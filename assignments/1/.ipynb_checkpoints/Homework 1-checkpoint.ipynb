# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 1

# %% [markdown]
# ## First we generate paths of 10000 stocks over 1000 periods

# %%
# define num of periods and num of stocks
periods = 1000
num_stocks = 10000

# a function to generate one stock path
def gen_one_path():
    p = [1]
    for i in range(1,periods):
        p.append((1+0.007*np.random.normal(0,1))*p[i-1])
    return np.array(p)

# %%
# store all paths into a list
paths = []
for i in range(num_stocks):
    paths.append(gen_one_path())

# %% [markdown]
# ## Plot 50 sample paths

# %%
for i in range(50):
    plt.plot(paths[i])

# %% [markdown]
# From the previous figure we can find that our stocks follow random walks, it makes sense.

# %% [markdown]
# ## Then we apply our selecting rule to generate Russell 1000 index

# %%
def update_index(start,end):
    """return the index from start time to end time
    
    start: the update time
    end: the next update time
    """
    index = np.repeat(0.0,end-start)
    path = []
    for i in paths:
        path.append(i[start])
    tops = np.argsort(path)[-1000:]
    for i in tops:
        index+=paths[i][start:end]
    return index/1000

# %%
# select stocks into Russell 1000 index
update_time = np.arange(1,1000,50)
update_time = np.append(update_time,1000)
index = np.array([])
index_mean = np.array([])
for i in range(1,len(update_time)):
    new_index = update_index(update_time[i-1],update_time[i])
    index=np.append(index, new_index)
index = np.append(1,index)

windows = np.arange(0,1001,100)
for i in range(1,len(windows)):
    mean = index[windows[i-1]:windows[i]].mean()
    index_mean = np.append(index_mean, mean)

# %% [markdown]
# ## Q1: Plot simulated Russell 1000 Index

# %%
plt.scatter(np.arange(0,1000,100),index_mean)

# %% [markdown]
# It seems reasonable because we select 1000 stocks with laregest market cap every 50 periods.

# %% [markdown]
# ## Average return of index

# %%
windows[-1]=999
re1 = np.array([])
for i in range(1,len(windows)):
    returns = np.log(index[windows[i]]) - np.log(index[windows[i-1]])
    re1 = np.append(re1,returns/100)

# %% [markdown]
# ## Q2: Plot the average return of Russell 1000 Index

# %%
plt.title("Average return of index")
plt.scatter(np.arange(0,1000,100),re1)
plt.plot(np.arange(0,1000,100),re1)
plt.show()

# %% [markdown]
# ## Average return of 10000 stocks

# %%
re2 = np.array([])
for i in range(1,len(windows)):
    returns = 0
    for j in paths:
        returns += np.log(j[i]) - np.log(j[i-1])
    re2 = np.append(re2,returns/100/len(paths))

# %% [markdown]
# ## Q3: Plot the average return of the 10,000 stocks

# %%
plt.title("averge return of 10000 stocks")
plt.scatter(np.arange(0,1000,100),re2)
plt.plot(np.arange(0,1000,100),re2)
plt.show()

# %% [markdown]
# ## Q4:

# %% [markdown]
# From the previous figure we can find that obviously the average return of Russell 1000 index is larger than the average return of 10000 stocks. Because in one window, we will always re-select the stocks that have the largest market cap, which makes the return of index go up. It cannot represent the general performance of 10000 stocks.

# %% [markdown]
# # Problem 2

# %% [markdown]
# ## Download data (11 ETFs and SPY)

# %%
import yfinance as yf
symbols = ['VOX','VCR', 'VDC', 'VDE', 'VFH', 'VHT', 'VIS', 'VGT', 'VAW', 'VNQ', 'VPU', 'SPY']
secs = ['COMM', 'CONSUMER DISC', 'CONSUMER ST', 'ENERGY', 'FINANCIALS', 'HEALTH', 'INDUSTRIALS', 
           'TECHNOLOGY', 'MATIREALS', 'REAL ESTATE', 'UTILITIES']
start = '2010-1-1'
end = '2020-12-31'
data = yf.download(symbols,start,end)['Adj Close']
# Out:
# [*********************100%***********************]  12 of 12 completed

# %% [markdown]
# ## Calculate log return

# %%
returns = np.log(data/data.shift(1))
returns = returns.dropna()

# %% [markdown]
# ## Q1: Plot the return processes of the 11 selected sector ETFs and the S&P 500 index.

# %%
for col in returns.columns:
    plt.plot(returns[col], label = col)
plt.legend()
plt.show()

# %% [markdown]
# ## The return of 11 etfs

# %%
df = returns.loc[:,['VOX','VCR', 'VDC', 'VDE', 'VFH', 'VHT', 'VIS', 'VGT', 'VAW', 'VNQ', 'VPU']]
df = df*100
df
# Out:
#                  VOX       VCR       VDC       VDE       VFH       VHT  \
# Date
# 2010-01-05  0.673417  0.634427  0.090387  1.018411  1.109832 -0.620777
# 2010-01-06 -1.595884  0.105346 -0.015065  1.144804  0.167106  0.566163
# 2010-01-07 -0.367856  0.859618  0.000000 -0.239337  1.918029  0.345426
# 2010-01-08 -0.457360  0.083453 -0.543564  0.750284 -0.393823  0.362320
# 2010-01-11  0.088119 -0.125210  0.347609 -0.079320 -0.032868  0.505053
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-23  0.677212  0.084619  0.414937  2.502538  1.632238  0.130804
# 2020-12-24  0.067481  0.194724  0.424812 -0.840017  0.041858  0.139632
# 2020-12-28  1.240058  0.796987  0.648302 -0.731199  0.375971 -0.297521
# 2020-12-29 -0.008320 -0.211413 -0.312052 -0.581059 -0.543521  0.153377
# 2020-12-30 -0.593026  0.571265  0.057864  1.637653  0.599089  0.144144
#
#                  VIS       VGT       VAW       VNQ       VPU
# Date
# 2010-01-05  0.436792 -0.107575  0.599309 -0.112279 -0.936118
# 2010-01-06  0.246038 -0.702126  1.398599 -0.179958  0.446107
# 2010-01-07  1.221267 -0.380135 -0.435859  1.074783 -0.446107
# 2010-01-08  1.317148  0.776809  1.079138 -0.737657 -0.107996
# 2010-01-11  0.935533 -0.432817 -0.335106  0.581665  0.768805
# ...              ...       ...       ...       ...       ...
# 2020-12-23  0.568656 -0.914369  0.278368 -0.648859 -0.172607
# 2020-12-24  0.064952  0.662475  0.535119  0.871695  0.599084
# 2020-12-28 -0.053144  0.700324 -0.405911  0.594320  0.565810
# 2020-12-29 -0.663662 -0.663496 -0.342756 -0.856932 -0.208075
# 2020-12-30  0.669570  0.133064  1.485406  0.548335  0.622942
#
# [2767 rows x 11 columns]

# %%
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer.factor_analyzer import calculate_kmo

# %% [markdown]
# ## Bartlett’s test of sphericity checks whether or not the observed variables intercorrelate at all

# %%
chi_square_value,p_value=calculate_bartlett_sphericity(df)
chi_square_value,p_value
# Out:
# (37302.50673827459, 0.0)

# %% [markdown]
# ## Kaiser-Meyer-Olkin (KMO) Test measures the suitability of data for factor analysis.

# %%
kmo_all,kmo_model=calculate_kmo(df)
kmo_model
# Out:
# 0.9471105112310753

# %% [markdown]
# ## Create factor analysis object and perform factor analysis

# %%
fa = FactorAnalyzer(n_factors=25, rotation=None)
fa.fit(df)
ev, v = fa.get_eigenvalues()

# %% [markdown]
# ## Create scree plot

# %%
# Create scree plot using matplotlib
plt.scatter(range(1,df.shape[1]+1),ev)
plt.plot(range(1,df.shape[1]+1),ev)
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# %% [markdown]
# ## Q2: use the varimax method to find a final rotated factor solution, which is the loadings

# %%
fa = FactorAnalyzer(n_factors=4, rotation="varimax")
fa.fit(df)
loadings = pd.DataFrame(fa.loadings_)
loadings.index = df.columns
loadings.columns = ['factor1','factor2','factor3','factor4']
loadings
# Out:
#       factor1   factor2   factor3   factor4
# VOX  0.412124  0.609747  0.378641  0.194088
# VCR  0.490577  0.727371  0.276853  0.263940
# VDC  0.324254  0.471882  0.719589  0.114409
# VDE  0.734165  0.313966  0.251493  0.157425
# VFH  0.674850  0.455871  0.333719  0.280677
# VHT  0.413111  0.623481  0.425571  0.145798
# VIS  0.702967  0.524178  0.342481  0.217564
# VGT  0.414552  0.772129  0.283419  0.169177
# VAW  0.730293  0.470085  0.320010  0.189978
# VNQ  0.366099  0.309026  0.529836  0.696974
# VPU  0.256919  0.218375  0.743711  0.273870

# %% [markdown]
# ## Regression and prediction

# %% [markdown]
# The model is
#
# $$
#     r_t = \mathbf{\beta}f_t + \epsilon_t
# $$
#
# Thus explicit regression formulation is
#     $$
#     \mathbf{R} = \mathbf{F} \mathbf{\beta^{\prime}} + \mathbf{E}
#     $$

# %%
from statsmodels.api import OLS, add_constant

# %%
factors = []
for period in returns.index:
    factor = OLS(endog=df.loc[period, loadings.index], exog=loadings).fit()
    factors.append(factor.params)

# %%
factors = pd.DataFrame(factors, index=returns.index, columns=loadings.columns.tolist())
factors.head()
# Out:
#              factor1   factor2   factor3   factor4
# Date
# 2010-01-05  1.841551 -0.236055 -1.308279 -0.009921
# 2010-01-06  2.527507 -2.165201  0.576585 -1.146205
# 2010-01-07  0.557905 -0.066811 -1.168171  2.384497
# 2010-01-08  1.702736  0.027926 -0.738740 -1.485695
# 2010-01-11 -0.063104 -0.592391  1.096775  0.306403

# %%
f = np.matrix(factors)
beta = np.matrix(loadings)
pred = beta.dot(f.transpose())
pred = pred.mean(axis=0)
pred = np.array(pred)

# %%
pred = pd.Series(pred.flatten())
pred.index = factors.index

# %%
spy = data['SPY']
spy_return = np.log(spy/spy.shift(1))*100
spy_return = spy_return.dropna()

# %% [markdown]
# ## return of the factor model

# %%
plt.plot(pred,label='pred')
plt.show()

# %% [markdown]
# ## Return of S&P500 index

# %%
plt.plot(spy_return)
plt.show()

# %% [markdown]
# ## Comparison between S&P500 and factor model

# %%
plt.plot(spy_return,label='spy')
plt.plot(pred,label='pred')
plt.legend()
plt.show()

# %% [markdown]
# ## Q3: Apply the factor sorting method

# %% [markdown]
# We now choose the facotr1 which is the most important factor and then we sort them:

# %%
factor_sort = loadings.loc[:,'factor1'] * factors.iloc[0,0]
factor_sort.index = secs

# %% [markdown]
# normalization

# %%
factor_sort = (factor_sort - factor_sort.mean())/factor_sort.std()
# Out:
# COMM            -0.509246
# CONSUMER DISC   -0.063781
# CONSUMER ST     -1.008180
# ENERGY           1.319335
# FINANCIALS       0.982536
# HEALTH          -0.503642
# INDUSTRIALS      1.142185
# TECHNOLOGY      -0.495462
# MATIREALS        1.297347
# REAL ESTATE     -0.770580
# UTILITIES       -1.390513
# Name: factor1, dtype: float64

# %%
factor_sort = factor_sort.sort_values()
factor_sort
# Out:
# UTILITIES       -1.390513
# CONSUMER ST     -1.008180
# REAL ESTATE     -0.770580
# COMM            -0.509246
# HEALTH          -0.503642
# TECHNOLOGY      -0.495462
# CONSUMER DISC   -0.063781
# FINANCIALS       0.982536
# INDUSTRIALS      1.142185
# MATIREALS        1.297347
# ENERGY           1.319335
# Name: factor1, dtype: float64

# %% [markdown]
# From the table above, we short the UTILITIES, CONSUMER ST, REAL ESTATE and long INDUSTRIALS, MATIREALS, ENERGY
